# %%
l = ['raju','sachin','saurabh','abhay']
for i,var in enumerate(l):
    print(i,var)
# Out:
# 0 raju
# 1 sachin
# 2 saurabh
# 3 abhay

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
x=[1,3,4,5]
y=[23,44,56,7]
sn.distplot(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 x=[1,3,4,5]
#       2 y=[23,44,56,7]
# ----> 3 sn.distplot(x,y,bin=20)
#
# TypeError: distplot() got an unexpected keyword argument 'bin'

# %%
data = pd.read_csv('https://raw.githubusercontent.com/andkoc001/Tips_dataset_analysis/master/tips.csv')
data.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           1       16.99  1.01  Female     No  Sun  Dinner     2
# 1           2       10.34  1.66    Male     No  Sun  Dinner     3
# 2           3       21.01  3.50    Male     No  Sun  Dinner     3
# 3           4       23.68  3.31    Male     No  Sun  Dinner     2
# 4           5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sn.pairplot(data,hue='sex',hue_order=['Female','Male'],markers=['*','h'])
